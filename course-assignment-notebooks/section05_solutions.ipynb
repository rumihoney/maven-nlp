# %% [markdown]
# # Solutions: Cleaning Data

# %% [markdown]
# ## 1. Data in Python Request

# %% [markdown]
# * Read in data from the Excel spreadsheet (Alarm Survey Data.xlsx) and put into a Pandas DataFrame
# * Check the data type of each column
# * Convert object columns into numeric or datetime columns, as needed

# %%
import pandas as pd

# %%
df = pd.read_excel('../Data/Alarm Survey Data.xlsx')
df.head()
# Out:
#    survey_id  age  number_of_children  activity_level  sleep_quality  \
# 0          1   34                 3.0          active            3.0
# 1          2   31                 3.0           light            3.0
# 2          3   18                 0.0  light_activity            4.0
# 3          4   42                 4.0          active            4.0
# 4          5   30                 1.0  light_activity            1.0
#
#    number_of_snoozes alarm_rating
# 0                  1      5 stars
# 1                  3      3 stars
# 2                  1      1 stars
# 3                  1      4 stars
# 4                  4      3 stars

# %%
df.dtypes
# Out:
# survey_id               int64
# age                     int64
# number_of_children    float64
# activity_level         object
# sleep_quality         float64
# number_of_snoozes       int64
# alarm_rating            int64
# dtype: object

# %%
# change the alarm rating column to a numeric column
df.alarm_rating = pd.to_numeric(df.alarm_rating.str.replace(' stars', ''))
df
# Out:
#       survey_id  age  number_of_children  activity_level  sleep_quality  \
# 0             1   34                 3.0          active            3.0
# 1             2   31                 3.0           light            3.0
# 2             3   18                 0.0  light_activity            4.0
# 3             4   42                 4.0          active            4.0
# 4             5   30                 1.0  light_activity            1.0
# ...         ...  ...                 ...             ...            ...
# 6428       6362   27                 2.0          active            5.0
# 6429       6363   31                 1.0           light            4.0
# 6430       6364   26                 0.0  lightly active            5.0
# 6431       6365   27                 1.0          active            5.0
# 6432       6366   18                 0.0  lightly active            4.0
#
#       number_of_snoozes  alarm_rating
# 0                     1             5
# 1                     3             3
# 2                     1             1
# 3                     1             4
# 4                     4             3
# ...                 ...           ...
# 6428                  0             5
# 6429                  0             4
# 6430                  0             3
# 6431                  0             3
# 6432                  0             1
#
# [6433 rows x 7 columns]

# %%
# number of children and sleep quality don't need to be floats - this will be addressed below

# %% [markdown]
# ## 2. Missing Data Check

# %% [markdown]
# * Find any missing data
# * Deal with the missing data

# %%
# check for missing data
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 6433 entries, 0 to 6432
# Data columns (total 7 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   survey_id           6433 non-null   int64
#  1   age                 6433 non-null   int64
#  2   number_of_children  6433 non-null   float64
#  3   activity_level      6433 non-null   object
#  4   sleep_quality       6082 non-null   float64
#  5   number_of_snoozes   6433 non-null   int64
#  6   alarm_rating        6433 non-null   int64
# dtypes: float64(2), int64(4), object(1)
# memory usage: 351.9+ KB

# %%
# see the rows with missing data
df[df.isna().any(axis=1)]
# Out:
#       survey_id  age  number_of_children  activity_level  sleep_quality  \
# 10           11   28                 2.0  light_activity            NaN
# 18           19   38                 2.0  lightly active            NaN
# 23           24   24                 2.0     very active            NaN
# 26           27   25                 2.0  lightly active            NaN
# 28           29   29                 2.0  lightly active            NaN
# ...         ...  ...                 ...             ...            ...
# 6310       6311   30                 2.0     very active            NaN
# 6319       6320   44                 2.0  lightly active            NaN
# 6375       6309   32                 3.0           light            NaN
# 6377       6311   30                 2.0     very active            NaN
# 6386       6320   44                 2.0  lightly active            NaN
#
#       number_of_snoozes  alarm_rating
# 10                    3             4
# 18                    1             5
# 23                    1             5
# 26                    1             2
# 28                    1             2
# ...                 ...           ...
# 6310                  0             3
# 6319                  0             3
# 6375                  0             3
# 6377                  0             3
# 6386                  0             3
#
# [351 rows x 7 columns]

# %%
# look at the sleep quality values
df.sleep_quality.value_counts(dropna=False)
# Out:
# sleep_quality
# 5.0    2721
# 4.0    2261
# 3.0     997
# NaN     351
# 1.0     103
# Name: count, dtype: int64

# %%
# update sleep quality NaNs to 2
df.sleep_quality.fillna(2, inplace=True)
# Out:
# C:\Users\lassa\AppData\Local\Temp\ipykernel_44028\1764036893.py:2: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df.sleep_quality.fillna(2, inplace=True)

# %%
# sleep quality values
df.sleep_quality.value_counts(dropna=False)
# Out:
# sleep_quality
# 5.0    2721
# 4.0    2261
# 3.0     997
# 2.0     351
# 1.0     103
# Name: count, dtype: int64

# %% [markdown]
# ## 3. Inconsistent Text & Typos Check

# %% [markdown]
# * Find any inconsistent text and typos
# * Deal with the inconsistent text and typos

# %%
# check the numerical columns
df.describe()
# Out:
#          survey_id          age  number_of_children  sleep_quality  \
# count  6433.000000  6433.000000         6433.000000    6433.000000
# mean   3216.302192    29.069175            1.395616       4.110835
# std    1856.007409     7.472048            1.432192       0.963415
# min       1.000000    13.000000            0.000000       1.000000
# 25%    1609.000000    23.000000            0.000000       4.000000
# 50%    3217.000000    28.000000            1.000000       4.000000
# 75%    4825.000000    34.000000            2.000000       5.000000
# max    6366.000000    47.000000            5.500000       5.000000
#
#        number_of_snoozes  alarm_rating
# count        6433.000000   6433.000000
# mean            1.145811      2.955075
# std             1.599481      1.101363
# min             0.000000      1.000000
# 25%             0.000000      2.000000
# 50%             0.000000      3.000000
# 75%             2.000000      4.000000
# max            19.000000      5.000000

# %%
# look into number of children -- it just means 5+ kids, leave as is
df.number_of_children.value_counts()
# Out:
# number_of_children
# 0.0    2440
# 2.0    1498
# 1.0    1172
# 3.0     788
# 4.0     331
# 5.5     204
# Name: count, dtype: int64

# %%
# check the categorical columms
df.activity_level.value_counts()
# Out:
# activity_level
# active            2450
# lightly active    2289
# light_activity     691
# very active        669
# light              334
# Name: count, dtype: int64

# %%
# map the lightly active values to one value
import numpy as np

df.activity_level = np.where(df.activity_level.isin(['light_activity', 'light']),
                             'lightly active',
                             df.activity_level)
df
# Out:
#       survey_id  age  number_of_children  activity_level  sleep_quality  \
# 0             1   34                 3.0          active            3.0
# 1             2   31                 3.0  lightly active            3.0
# 2             3   18                 0.0  lightly active            4.0
# 3             4   42                 4.0          active            4.0
# 4             5   30                 1.0  lightly active            1.0
# ...         ...  ...                 ...             ...            ...
# 6428       6362   27                 2.0          active            5.0
# 6429       6363   31                 1.0  lightly active            4.0
# 6430       6364   26                 0.0  lightly active            5.0
# 6431       6365   27                 1.0          active            5.0
# 6432       6366   18                 0.0  lightly active            4.0
#
#       number_of_snoozes  alarm_rating
# 0                     1             5
# 1                     3             3
# 2                     1             1
# 3                     1             4
# 4                     4             3
# ...                 ...           ...
# 6428                  0             5
# 6429                  0             4
# 6430                  0             3
# 6431                  0             3
# 6432                  0             1
#
# [6433 rows x 7 columns]

# %%
# check the categorical columms
df.activity_level.value_counts()
# Out:
# activity_level
# lightly active    3314
# active            2450
# very active        669
# Name: count, dtype: int64

# %% [markdown]
# ## 4. Duplicate Data Check

# %% [markdown]
# * Find any duplicate data
# * Deal with the duplicate data

# %%
# check for duplicate values
df[df.duplicated()]
# Out:
#       survey_id  age  number_of_children  activity_level  sleep_quality  \
# 6366       6300   31                 2.0          active            5.0
# 6367       6301   27                 2.0  lightly active            4.0
# 6368       6302   41                 3.0  lightly active            5.0
# 6369       6303   25                 0.0  lightly active            5.0
# 6370       6304   25                 1.0  lightly active            5.0
# ...         ...  ...                 ...             ...            ...
# 6428       6362   27                 2.0          active            5.0
# 6429       6363   31                 1.0  lightly active            4.0
# 6430       6364   26                 0.0  lightly active            5.0
# 6431       6365   27                 1.0          active            5.0
# 6432       6366   18                 0.0  lightly active            4.0
#
#       number_of_snoozes  alarm_rating
# 6366                  0             3
# 6367                  0             2
# 6368                  0             2
# 6369                  0             5
# 6370                  0             2
# ...                 ...           ...
# 6428                  0             5
# 6429                  0             4
# 6430                  0             3
# 6431                  0             3
# 6432                  0             1
#
# [67 rows x 7 columns]

# %%
# drop duplicates
df.drop_duplicates()
# Out:
#       survey_id  age  number_of_children  activity_level  sleep_quality  \
# 0             1   34                 3.0          active            3.0
# 1             2   31                 3.0  lightly active            3.0
# 2             3   18                 0.0  lightly active            4.0
# 3             4   42                 4.0          active            4.0
# 4             5   30                 1.0  lightly active            1.0
# ...         ...  ...                 ...             ...            ...
# 6361       6362   27                 2.0          active            5.0
# 6362       6363   31                 1.0  lightly active            4.0
# 6363       6364   26                 0.0  lightly active            5.0
# 6364       6365   27                 1.0          active            5.0
# 6365       6366   18                 0.0  lightly active            4.0
#
#       number_of_snoozes  alarm_rating
# 0                     1             5
# 1                     3             3
# 2                     1             1
# 3                     1             4
# 4                     4             3
# ...                 ...           ...
# 6361                  0             5
# 6362                  0             4
# 6363                  0             3
# 6364                  0             3
# 6365                  0             1
#
# [6366 rows x 7 columns]

# %%
# alternative: save non-duplicates
df = df[~df.duplicated()]
df
# Out:
#       survey_id  age  number_of_children  activity_level  sleep_quality  \
# 0             1   34                 3.0          active            3.0
# 1             2   31                 3.0  lightly active            3.0
# 2             3   18                 0.0  lightly active            4.0
# 3             4   42                 4.0          active            4.0
# 4             5   30                 1.0  lightly active            1.0
# ...         ...  ...                 ...             ...            ...
# 6361       6362   27                 2.0          active            5.0
# 6362       6363   31                 1.0  lightly active            4.0
# 6363       6364   26                 0.0  lightly active            5.0
# 6364       6365   27                 1.0          active            5.0
# 6365       6366   18                 0.0  lightly active            4.0
#
#       number_of_snoozes  alarm_rating
# 0                     1             5
# 1                     3             3
# 2                     1             1
# 3                     1             4
# 4                     4             3
# ...                 ...           ...
# 6361                  0             5
# 6362                  0             4
# 6363                  0             3
# 6364                  0             3
# 6365                  0             1
#
# [6366 rows x 7 columns]

# %% [markdown]
# ## 5. Outliers Check

# %% [markdown]
# * Find any outliers
# * Deal with the outliers

# %%
# look at the histograms of all numeric columns
df.hist(figsize = (6,8));

# %%
# look at the histogram of the number of snoozes
import seaborn as sns

sns.histplot(df.number_of_snoozes);

# %%
# look at the boxplot of the number of snoozes
sns.boxplot(x=df.number_of_snoozes);

# %%
# look into number of snoozes
df.number_of_snoozes.value_counts()
# Out:
# number_of_snoozes
# 0     3300
# 1     1229
# 2      693
# 4      427
# 5      345
# 3      309
# 6       59
# 8        2
# 19       1
# 7        1
# Name: count, dtype: int64

# %%
# let's only remove the extreme outlier
df = df[df.number_of_snoozes < 19]
df
# Out:
#       survey_id  age  number_of_children  activity_level  sleep_quality  \
# 0             1   34                 3.0          active            3.0
# 1             2   31                 3.0  lightly active            3.0
# 2             3   18                 0.0  lightly active            4.0
# 3             4   42                 4.0          active            4.0
# 4             5   30                 1.0  lightly active            1.0
# ...         ...  ...                 ...             ...            ...
# 6361       6362   27                 2.0          active            5.0
# 6362       6363   31                 1.0  lightly active            4.0
# 6363       6364   26                 0.0  lightly active            5.0
# 6364       6365   27                 1.0          active            5.0
# 6365       6366   18                 0.0  lightly active            4.0
#
#       number_of_snoozes  alarm_rating
# 0                     1             5
# 1                     3             3
# 2                     1             1
# 3                     1             4
# 4                     4             3
# ...                 ...           ...
# 6361                  0             5
# 6362                  0             4
# 6363                  0             3
# 6364                  0             3
# 6365                  0             1
#
# [6365 rows x 7 columns]

# %% [markdown]
# ## 6. Data Issues Check

# %% [markdown]
# * Quickly explore the updated DataFrame. How do things look now after handling the data issues compared to the original DataFrame?

# %%
# check for missing values
df[df.isna().any(axis=1)]
# Out:
# Empty DataFrame
# Columns: [survey_id, age, number_of_children, activity_level, sleep_quality, number_of_snoozes, alarm_rating]
# Index: []

# %%
# check for inconsistent text
df.activity_level.value_counts()
# Out:
# activity_level
# lightly active    3287
# active            2422
# very active        656
# Name: count, dtype: int64

# %%
# check for duplicate values
df[df.duplicated()]
# Out:
# Empty DataFrame
# Columns: [survey_id, age, number_of_children, activity_level, sleep_quality, number_of_snoozes, alarm_rating]
# Index: []

# %%
# check for outliers
df.describe()
# Out:
#          survey_id          age  number_of_children  sleep_quality  \
# count  6365.000000  6365.000000         6365.000000    6365.000000
# mean   3183.882325    29.076826            1.396936       4.107620
# std    1837.741432     7.476376            1.433575       0.963612
# min       1.000000    13.000000            0.000000       1.000000
# 25%    1593.000000    23.000000            0.000000       4.000000
# 50%    3184.000000    28.000000            1.000000       4.000000
# 75%    4775.000000    34.000000            2.000000       5.000000
# max    6366.000000    47.000000            5.500000       5.000000
#
#        number_of_snoozes  alarm_rating
# count        6365.000000   6365.000000
# mean            1.155067      2.955224
# std             1.587979      1.100414
# min             0.000000      1.000000
# 25%             0.000000      2.000000
# 50%             0.000000      3.000000
# 75%             2.000000      4.000000
# max             8.000000      5.000000

# %%
# first round of data cleaning is complete!
df.head()
# Out:
#    survey_id  age  number_of_children  activity_level  sleep_quality  \
# 0          1   34                 3.0          active            3.0
# 1          2   31                 3.0  lightly active            3.0
# 2          3   18                 0.0  lightly active            4.0
# 3          4   42                 4.0          active            4.0
# 4          5   30                 1.0  lightly active            1.0
#
#    number_of_snoozes  alarm_rating
# 0                  1             5
# 1                  3             3
# 2                  1             1
# 3                  1             4
# 4                  4             3

# %% [markdown]
# ## 7. Create Columns From Numeric Data

# %% [markdown]
# * Read data into Python
# * Check the data type of each column
# * Create a numeric column using arithmetic
# * Create a numeric column using conditional logic

# %%
import pandas as pd

# read in data
pens = pd.read_excel('../Data/Pen Sales Data.xlsx')
pens.head()
# Out:
#    Customer                   Item  Pen Cost  Shipping Cost Purchase Date  \
# 0      5201         Ballpoint Pens      5.99           2.99    2023-05-01
# 1      5202               Sharpies     12.99           0.00    2023-05-01
# 2      5203  Ballpoint Pens (Bold)      6.95           4.99    2023-05-01
# 3      5204               Gel Pens      5.99           2.99    2023-05-01
# 4      5205        Rollerball Pens     12.99           1.99    2023-05-01
#
#   Delivery Date                                             Review
# 0    2023-05-03  DoodleWithMe|I love the way this pen writes, b...
# 1    2023-05-04  ScribbleMaster|The classic Sharpie marker has ...
# 2    2023-05-02  PenPalForever|The retractable ballpoint pen ha...
# 3    2023-05-04  TheWriteWay|This gel pen has a comfortable gri...
# 4    2023-05-03  PenAndPaperPerson|The rollerball pen has a smo...

# %%
# check the data types
pens.dtypes
# Out:
# Customer                  int64
# Item                     object
# Pen Cost                float64
# Shipping Cost           float64
# Purchase Date    datetime64[ns]
# Delivery Date    datetime64[ns]
# Review                   object
# dtype: object

# %%
# create a new column using addition
pens['Total Spend'] = pens['Pen Cost'] + pens['Shipping Cost']
pens.head()
# Out:
#    Customer                   Item  Pen Cost  Shipping Cost Purchase Date  \
# 0      5201         Ballpoint Pens      5.99           2.99    2023-05-01
# 1      5202               Sharpies     12.99           0.00    2023-05-01
# 2      5203  Ballpoint Pens (Bold)      6.95           4.99    2023-05-01
# 3      5204               Gel Pens      5.99           2.99    2023-05-01
# 4      5205        Rollerball Pens     12.99           1.99    2023-05-01
#
#   Delivery Date                                             Review  \
# 0    2023-05-03  DoodleWithMe|I love the way this pen writes, b...
# 1    2023-05-04  ScribbleMaster|The classic Sharpie marker has ...
# 2    2023-05-02  PenPalForever|The retractable ballpoint pen ha...
# 3    2023-05-04  TheWriteWay|This gel pen has a comfortable gri...
# 4    2023-05-03  PenAndPaperPerson|The rollerball pen has a smo...
#
#    Total Spend
# 0         8.98
# 1        12.99
# 2        11.94
# 3         8.98
# 4        14.98

# %%
import numpy as np

# create a new column using conditional logic
pens['Free Shipping'] = np.where(pens['Shipping Cost'] == 0, 'Yes', 'No')
pens.head()
# Out:
#    Customer                   Item  Pen Cost  Shipping Cost Purchase Date  \
# 0      5201         Ballpoint Pens      5.99           2.99    2023-05-01
# 1      5202               Sharpies     12.99           0.00    2023-05-01
# 2      5203  Ballpoint Pens (Bold)      6.95           4.99    2023-05-01
# 3      5204               Gel Pens      5.99           2.99    2023-05-01
# 4      5205        Rollerball Pens     12.99           1.99    2023-05-01
#
#   Delivery Date                                             Review  \
# 0    2023-05-03  DoodleWithMe|I love the way this pen writes, b...
# 1    2023-05-04  ScribbleMaster|The classic Sharpie marker has ...
# 2    2023-05-02  PenPalForever|The retractable ballpoint pen ha...
# 3    2023-05-04  TheWriteWay|This gel pen has a comfortable gri...
# 4    2023-05-03  PenAndPaperPerson|The rollerball pen has a smo...
#
#    Total Spend Free Shipping
# 0         8.98            No
# 1        12.99           Yes
# 2        11.94            No
# 3         8.98            No
# 4        14.98            No

# %% [markdown]
# ## 8. Create Columns From DateTime Data

# %% [markdown]
# * Calculate the difference between two datetime columns and save it as a new column
# * Take the average of a column

# %%
# apply a datetime calculation
pens['Delivery Time'] = pens['Delivery Date'] - pens['Purchase Date']
pens.head()
# Out:
#    Customer                   Item  Pen Cost  Shipping Cost Purchase Date  \
# 0      5201         Ballpoint Pens      5.99           2.99    2023-05-01
# 1      5202               Sharpies     12.99           0.00    2023-05-01
# 2      5203  Ballpoint Pens (Bold)      6.95           4.99    2023-05-01
# 3      5204               Gel Pens      5.99           2.99    2023-05-01
# 4      5205        Rollerball Pens     12.99           1.99    2023-05-01
#
#   Delivery Date                                             Review  \
# 0    2023-05-03  DoodleWithMe|I love the way this pen writes, b...
# 1    2023-05-04  ScribbleMaster|The classic Sharpie marker has ...
# 2    2023-05-02  PenPalForever|The retractable ballpoint pen ha...
# 3    2023-05-04  TheWriteWay|This gel pen has a comfortable gri...
# 4    2023-05-03  PenAndPaperPerson|The rollerball pen has a smo...
#
#    Total Spend Free Shipping Delivery Time
# 0         8.98            No        2 days
# 1        12.99           Yes        3 days
# 2        11.94            No        1 days
# 3         8.98            No        3 days
# 4        14.98            No        2 days

# %%
# see the output of a datetime calculation
pens['Delivery Time'].mean()
# Out:
# Timedelta('3 days 05:45:36')

# %% [markdown]
# ## 9. Create Columns From Text Data

# %% [markdown]
# * Split one column into multiple columns
# * Create a Boolean column (True / False) to show whether a text field contains particular words

# %%
# split a column into multiple columns
reviews = pens.Review.str.split('|')
reviews.head()
# Out:
# 0    [DoodleWithMe, I love the way this pen writes,...
# 1    [ScribbleMaster, The classic Sharpie marker ha...
# 2    [PenPalForever, The retractable ballpoint pen ...
# 3    [TheWriteWay, This gel pen has a comfortable g...
# 4    [PenAndPaperPerson, The rollerball pen has a s...
# Name: Review, dtype: object

# %%
# put columns back into original dataframe
pens[['User Name', 'Review Text']] = pd.DataFrame(reviews.to_list())
pens
# Out:
#     Customer                   Item  Pen Cost  Shipping Cost Purchase Date  \
# 0       5201         Ballpoint Pens      5.99           2.99    2023-05-01
# 1       5202               Sharpies     12.99           0.00    2023-05-01
# 2       5203  Ballpoint Pens (Bold)      6.95           4.99    2023-05-01
# 3       5204               Gel Pens      5.99           2.99    2023-05-01
# 4       5205        Rollerball Pens     12.99           1.99    2023-05-01
# 5       5206      Gel Pens (Pastel)     14.99           1.99    2023-05-01
# 6       5207        Rollerball Pens     12.99           1.99    2023-05-01
# 7       5208        Rollerball Pens     12.99           1.99    2023-05-01
# 8       5209               Gel Pens      5.99           2.99    2023-05-01
# 9       5210      Gel Pens (Pastel)     14.99           4.99    2023-05-01
# 10      5211  Ballpoint Pens (Bold)      6.95           0.00    2023-05-01
# 11      5212  Ballpoint Pens (Bold)      6.95           2.99    2023-05-01
# 12      5213               Sharpies     12.99           1.99    2023-05-01
# 13      5214        Rollerball Pens     12.99           1.99    2023-05-01
# 14      5215         Ballpoint Pens      5.99           1.99    2023-05-01
# 15      5216               Gel Pens      5.99           0.00    2023-05-02
# 16      5217               Sharpies     12.99           2.99    2023-05-02
# 17      5218      Gel Pens (Pastel)     14.99           4.99    2023-05-02
# 18      5219         Ballpoint Pens      5.99           0.00    2023-05-02
# 19      5220               Gel Pens      5.99           0.00    2023-05-02
# 20      5221               Sharpies     12.99           1.99    2023-05-02
# 21      5222         Ballpoint Pens      5.99           1.99    2023-05-02
# 22      5223  Ballpoint Pens (Bold)      6.95           0.00    2023-05-02
# 23      5224               Sharpies     12.99           2.99    2023-05-02
# 24      5225  Ballpoint Pens (Bold)      6.95           2.99    2023-05-02
#
#    Delivery Date                                             Review  \
# 0     2023-05-03  DoodleWithMe|I love the way this pen writes, b...
# 1     2023-05-04  ScribbleMaster|The classic Sharpie marker has ...
# 2     2023-05-02  PenPalForever|The retractable ballpoint pen ha...
# 3     2023-05-04  TheWriteWay|This gel pen has a comfortable gri...
# 4     2023-05-03  PenAndPaperPerson|The rollerball pen has a smo...
# 5     2023-05-04  SmoothOperatorPen|This gel pen writes smoothly...
# 6     2023-05-03  InkStainedFingers|This pen is prone to leaking...
# 7     2023-05-07  BoldInkWriter|Unfortunately, this pen has a te...
# 8     2023-05-06  PenmanshipPro|The gel pen has a comfortable gr...
# 9     2023-05-02  GelPenGuru|This retractable gel pen has a fine...
# 10    2023-05-04  FinePointFan|Be careful with this pen, as it h...
# 11    2023-05-07  SignatureStylePen|The retractable ballpoint pe...
# 12    2023-05-03                               BoldAndBeautifulPen|
# 13    2023-05-07  RollerballRider|The ink in this pen has a tend...
# 14    2023-05-03  BallpointBandit|This ballpoint pen has a sleek...
# 15    2023-05-04  TwistAndWriteUser|The ink in this pen can some...
# 16    2023-05-04                                   ThePenWhisperer|
# 17    2023-05-03  InkFlowFollower|I was disappointed to find tha...
# 18    2023-05-07  ThePenAndInkLady|This ballpoint pen has a comf...
# 19    2023-05-07  WritingInstrumentsFan|This pen is great for wr...
# 20    2023-05-05  PenPrecisionPro|The retractable Sharpie marker...
# 21    2023-05-05  InkCollector|The ballpoint pen is lightweight ...
# 22    2023-05-06                             PenToPaperPersonality|
# 23    2023-05-06  SmoothWritingScribe|This fine point Sharpie ma...
# 24    2023-05-07  ThePenmanshipPundit|This pen writes smoothly a...
#
#     Total Spend Free Shipping Delivery Time              User Name  \
# 0          8.98            No        2 days           DoodleWithMe
# 1         12.99           Yes        3 days         ScribbleMaster
# 2         11.94            No        1 days          PenPalForever
# 3          8.98            No        3 days            TheWriteWay
# 4         14.98            No        2 days      PenAndPaperPerson
# 5         16.98            No        3 days      SmoothOperatorPen
# 6         14.98            No        2 days      InkStainedFingers
# 7         14.98            No        6 days          BoldInkWriter
# 8          8.98            No        5 days          PenmanshipPro
# 9         19.98            No        1 days             GelPenGuru
# 10         6.95           Yes        3 days           FinePointFan
# 11         9.94            No        6 days      SignatureStylePen
# 12        14.98            No        2 days    BoldAndBeautifulPen
# 13        14.98            No        6 days        RollerballRider
# 14         7.98            No        2 days        BallpointBandit
# 15         5.99           Yes        2 days      TwistAndWriteUser
# 16        15.98            No        2 days        ThePenWhisperer
# 17        19.98            No        1 days        InkFlowFollower
# 18         5.99           Yes        5 days       ThePenAndInkLady
# 19         5.99           Yes        5 days  WritingInstrumentsFan
# 20        14.98            No        3 days        PenPrecisionPro
# 21         7.98            No        3 days           InkCollector
# 22         6.95           Yes        4 days  PenToPaperPersonality
# 23        15.98            No        4 days    SmoothWritingScribe
# 24         9.94            No        5 days    ThePenmanshipPundit
#
#                                           Review Text
# 0   I love the way this pen writes, but unfortunat...
# 1   The classic Sharpie marker has a bold, permane...
# 2   The retractable ballpoint pen has a durable, m...
# 3   This gel pen has a comfortable grip and writes...
# 4   The rollerball pen has a smooth, fluid feel an...
# 5   This gel pen writes smoothly with a bold, vibr...
# 6   This pen is prone to leaking and can create a ...
# 7   Unfortunately, this pen has a tendency to spil...
# 8   The gel pen has a comfortable grip and writes ...
# 9   This retractable gel pen has a fine point that...
# 10  Be careful with this pen, as it has been known...
# 11  The retractable ballpoint pen is convenient an...
# 12
# 13  The ink in this pen has a tendency to leak out...
# 14  This ballpoint pen has a sleek design and writ...
# 15  The ink in this pen can sometimes leak out of ...
# 16
# 17  I was disappointed to find that this pen leake...
# 18  This ballpoint pen has a comfortable grip and ...
# 19  This pen is great for writing, but it's not ve...
# 20  The retractable Sharpie marker is convenient a...
# 21  The ballpoint pen is lightweight and comfortab...
# 22
# 23  This fine point Sharpie marker has a precise t...
# 24  This pen writes smoothly and delivers a crisp ...

# %%
# find if a field contains particular words
pens['Leak or Spill'] = pens.Review.str.contains('leak|spill', regex=True)
pens.head()
# Out:
#    Customer                   Item  Pen Cost  Shipping Cost Purchase Date  \
# 0      5201         Ballpoint Pens      5.99           2.99    2023-05-01
# 1      5202               Sharpies     12.99           0.00    2023-05-01
# 2      5203  Ballpoint Pens (Bold)      6.95           4.99    2023-05-01
# 3      5204               Gel Pens      5.99           2.99    2023-05-01
# 4      5205        Rollerball Pens     12.99           1.99    2023-05-01
#
#   Delivery Date                                             Review  \
# 0    2023-05-03  DoodleWithMe|I love the way this pen writes, b...
# 1    2023-05-04  ScribbleMaster|The classic Sharpie marker has ...
# 2    2023-05-02  PenPalForever|The retractable ballpoint pen ha...
# 3    2023-05-04  TheWriteWay|This gel pen has a comfortable gri...
# 4    2023-05-03  PenAndPaperPerson|The rollerball pen has a smo...
#
#    Total Spend Free Shipping Delivery Time          User Name  \
# 0         8.98            No        2 days       DoodleWithMe
# 1        12.99           Yes        3 days     ScribbleMaster
# 2        11.94            No        1 days      PenPalForever
# 3         8.98            No        3 days        TheWriteWay
# 4        14.98            No        2 days  PenAndPaperPerson
#
#                                          Review Text  Leak or Spill
# 0  I love the way this pen writes, but unfortunat...           True
# 1  The classic Sharpie marker has a bold, permane...          False
# 2  The retractable ballpoint pen has a durable, m...          False
# 3  This gel pen has a comfortable grip and writes...          False
# 4  The rollerball pen has a smooth, fluid feel an...          False
